# %% [markdown]
# # Análisis del Mercado de Criptomonedas
#
# ## Introducción
#
# En los últimos años, las criptomonedas han emergido como un activo fascinante, atractivo tanto por su alta volatilidad como por su potencial de inversión.
#
# El mercado, caracterizado por su naturaleza descentralizada, está influenciado por diversas fuerzas, desde la oferta y la demanda hasta eventos globales. En esta presentación, exploraremos la volatilidad de las criptomonedas mediante análisis descriptivos y pruebas estadísticas, como la prueba de Wilcoxon y el análisis de varianza, para evaluar cómo los eventos impactan este mercado.
#
# Además, examinaremos las relaciones entre factores como el volumen de transacciones y la volatilidad, buscando patrones que puedan guiar decisiones de inversión. Acompáñanos a descubrir los elementos clave que configuran este dinámico sector financiero.

# %% [markdown]
# # Presentación de los Datos
# Analizaremos las variables clave, sus tipos, y proporcionaremos un resumen estadístico para ofrecer una visión general del comportamiento de las criptomonedas

# %%
import pandas as pd

# Cargar el archivo CSV
data = pd.read_csv("../db/merge/merge.csv")

# Mostrar las primeras filas del conjunto de datos
print("Primeras filas del conjunto de datos:")
print(data.head())

# Mostrar un resumen estadístico de las variables numéricas
print("\nResumen estadístico de las variables numéricas:")
print(data.describe())

# Mostrar las columnas disponibles en el conjunto de datos
print("\nColumnas en el conjunto de datos:")
print(data.columns)
# Out:
# Primeras filas del conjunto de datos:
#                   date   symbol    open    high     low  volatility  average  \
# 0  2025-01-24 00:00:00  LTC/USD  116.25  116.25  114.00    0.019355   114.00
# 1  2025-01-23 00:00:00  LTC/USD  115.15  117.10  111.26    0.050716   116.41
# 2  2025-01-22 00:00:00  LTC/USD  118.78  120.25  114.18    0.051103   115.46
# 3  2025-01-21 00:00:00  LTC/USD  118.76  124.82  113.66    0.093971   119.09
# 4  2025-01-20 00:00:00  LTC/USD  115.63  127.28  112.89    0.124449   118.46
#
#     returns   close    volume usd  volume cripto
# 0 -0.019355  114.00  5.804406e+03      50.915841
# 1  0.010942  116.41  1.822044e+06   15651.951746
# 2 -0.027951  115.46  1.250519e+06   10830.758412
# 3  0.002779  119.09  3.582117e+06   30079.076636
# 4  0.024475  118.46  4.267069e+06   36021.178073
#
# Resumen estadístico de las variables numéricas:
#                 open           high            low    volatility  \
# count   43222.000000   43222.000000   43222.000000  43222.000000
# mean     1867.883481    1913.567753    1819.443792      0.078219
# std      8827.756933    9031.103655    8616.395888      0.074693
# min         0.001410       0.001464       0.000310      0.000000
# 25%         0.331440       0.348695       0.315132      0.035708
# 50%         4.364500       4.573500       4.159150      0.060164
# 75%        64.768250      66.562500      62.500000      0.098284
# max    106150.000000  109590.000000  105110.000000      2.679900
#
#              average       returns          close    volume usd  volume cripto
# count   42980.000000  43222.000000   43222.000000  4.322200e+04   4.322200e+04
# mean     1879.544884      0.001729    1870.353932  1.808586e+07   1.533673e+06
# std      8864.188864      0.059907    8841.318797  7.484660e+07   9.431196e+06
# min         0.001411     -0.644670       0.001411  0.000000e+00   0.000000e+00
# 25%         0.327102     -0.022328       0.330855  3.534534e+04   9.739298e+03
# 50%         4.266819      0.000000       4.363000  3.099140e+05   6.709260e+04
# 75%        65.266250      0.022462      64.796000  3.797955e+06   4.208191e+05
# max    106150.000000      1.563877  106150.000000  2.491339e+09   7.136161e+08
#
# Columnas en el conjunto de datos:
# Index(['date', 'symbol', 'open', 'high', 'low', 'volatility', 'average',
#        'returns', 'close', 'volume usd', 'volume cripto'],
#       dtype='object')

# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
# Se realizó un análisis exploratorio de datos (EDA) para comprender mejor la dinámica del mercado de criptomonedas, con el objetivo de identificar patrones, detectar anomalías y evaluar la relación entre variables clave como, por ejemplo, la volatilidad y el volumen de transacciones.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import EDA as eda
import importlib
importlib.reload(eda)

eda.describe(1000, 'BTC/USD')
# Out:
# Estadísticas de Precio de Cierre para BTC/USD:
# Media: 42406.24018532766, Mediana: 30287.0, Moda: 19944.0
#
# Estadísticas de Precio Máximo para BTC/USD:
# Media: 43195.87318983385, Mediana: 30769.0, Moda: 71444.0
#
# Estadísticas de Precio Mínimo para BTC/USD:
# Media: 41502.6375404881, Mediana: 29833.0, Moda: 16410.0
#
# Estadísticas de Volumen USD para BTC/USD:
# Media: 83564668.41370344, Mediana: 52476871.63156174, Moda: 297161.2913881
#
# Estadísticas de Volumen Cripto para BTC/USD:
# Media: 2486.5174647066733, Mediana: 1373.60238417, Moda: 2.86752187

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import EDA as eda
import importlib
importlib.reload(eda)

eda.analice('open', 10000)

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import EDA as eda
import importlib
importlib.reload(eda)

eda.correlation(100)

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import EDA as eda
import importlib
importlib.reload(eda)

eda.attipic_values(10000, 'open', 'low')

# %% [markdown]
# # Analisis de Distribución de la variable Volatilidad
# Se llevó a cabo un análisis de las posibles distribuciones de la variable volatilidad para comprender su comportamiento en el contexto del mercado de criptomonedas. Este análisis es crucial por varias razones. En primer lugar, conocer la distribución de la volatilidad nos permite identificar patrones y tendencias que pueden influir en nuestras decisiones de inversión. Además, facilita la detección de valores atípicos y anomalías, lo que puede indicar cambios significativos en el mercado o errores en los datos.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import Analisis_Distribucion as ad 

import importlib
importlib.reload(ad)
ad.show_dist('volatility', 50)

ad.test_de_bondad('volatility', 50)
# Out:
# (np.float64(0.07219851249693066), np.float64(0.05501779827663849))
# (np.float64(111.56556093936084), np.float64(-5e-324), np.float64(1.8323897971834395e-09))
# (0.0, 0.07219851249693066)
# (np.float64(58094050.85090227), np.float64(-4194303.999999998), np.float64(4194303.9999999977))
# (np.float64(1.7407339167216223), np.float64(12.759483551749165), np.float64(-0.004840391618656409), np.float64(0.6453089699444156))
# (np.float64(143102973.80331612), np.float64(5519409.089726377), np.float64(5519409.040684016))
# (np.float64(0.0659817038926991), np.float64(0.027676362445079036))
# (np.float64(0.04903752724809453), 0.03855742146096115)
# (np.float64(3.336754910014292), np.float64(0.06289497873026632), np.float64(0.035926289596640064))
# Prueba K-S para weibull_max: estadístico = 0.041014700820378266, valor p = 0.29382250365849516
# Los datos podrían seguir la distribución weibull_max (K-S test).
#
# Prueba K-S para gumbel_r: estadístico = 0.04104774454108212, valor p = 0.2929317090960062
# Los datos podrían seguir la distribución gumbel_r (K-S test).
#
# Prueba K-S para norm: estadístico = 0.11185774503361268, valor p = 1.4354396095713932e-06
# Los datos no siguen la distribución norm (K-S test).
#
# Prueba K-S para lognorm: estadístico = 0.5200094296043701, valor p = 1.2489133344502433e-141
# Los datos no siguen la distribución lognorm (K-S test).
#
# Prueba K-S para expon: estadístico = 0.1693528472101633, valor p = 1.5538070197883297e-14
# Los datos no siguen la distribución expon (K-S test).
#
# Prueba K-S para pareto: estadístico = 0.1693528558825541, valor p = 1.5538018248952132e-14
# Los datos no siguen la distribución pareto (K-S test).
#
# Prueba K-S para beta: estadístico = 0.06128713434979077, valor p = 0.028326348722867767
# Los datos no siguen la distribución beta (K-S test).
#
# Prueba K-S para logistic: estadístico = 0.08439743531354395, valor p = 0.0006332295868884153
# Los datos no siguen la distribución logistic (K-S test).
#
# Prueba K-S para t: estadístico = 0.08448599338778408, valor p = 0.0006226261259775856
# Los datos no siguen la distribución t (K-S test).
#
# Estadístico KS: [0.12741501]
# P-valor: [2.12602079e-08]
# Se rechaza la hipótesis nula: la muestra no sigue una distribución de Cauchy.

# %% [markdown]
# # Matriz de Correlación
# El análisis de la matriz de correlación, utilizando el método de Spearman, tiene como objetivo identificar y cuantificar la relación entre múltiples variables en el contexto del mercado de criptomonedas. Este análisis permite revelar patrones y dependencias que pueden no ser evidentes al observar las variables de forma aislada. Entender estas correlaciones es fundamental para optimizar estrategias de inversión, diversificar riesgos y mejorar la toma de decisiones informadas en un entorno volátil.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import Correlacion as corr

corr.correlation_matrix(100, ['open', 'close', 'high', 'low', 'average', 'volume usd', 'volume cripto', 'volatility', 'returns'])

# %% [markdown]
# # Analisis de posibles resultados
# El análisis de la matriz de correlación puede revelar relaciones significativas entre variables. Un coeficiente de correlación positivo indicaría que a medida que aumenta una variable también lo hará a otra. Por otro lado, una correlación negativa podría indicar que aumentos en una variable están asociados con disminuciones en otra, lo que es crucial para identificar posibles riesgos e influencias en la toma de decisiones de inversión. Estos resultados informan sobre la interconexión de factores en el mercado de criptomonedas, ayudando a diseñar estrategias más efectivas.

# %% [markdown]
# # Regresiones
# El objetivo de analizar la relación entre las variables 'open' (precio de apertura) y 'high' (precio máximo) en el contexto del mercado de criptomonedas es determinar cómo el precio de apertura influye en el precio máximo alcanzado durante el día. Con un coeficiente de correlación de Spearman de 1, hemos encontrado que existe una correlación perfecta entre estas variables, lo que indica que un aumento en el precio de apertura se asocia directamente con un incremento en el precio máximo del día.
#
# Para profundizar en esta relación, se llevará a cabo una regresión lineal que permitirá calcular los coeficientes y la constante de la recta que las relaciona. Este análisis ofrecerá una comprensión más detallada del grado de dependencia entre 'open' y 'high', proporcionando una herramienta analítica que ayudará a los inversores a identificar patrones de comportamiento y a tomar decisiones informadas. Con esta información, los traders podrán maximizar sus oportunidades de beneficio al invertir en criptomonedas en momentos óptimos, gestionando de manera eficiente el riesgo en un entorno de inversión altamente volátil.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import regresion_simple as rs 
import importlib
importlib.reload(rs)

rs.simple_regresion(1000, 'volatility', 'returns', 'BTC/USD')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     1867.
# Date:                Fri, 14 Feb 2025   Prob (F-statistic):          7.29e-231
# Time:                        23:28:50   Log-Likelihood:                 3010.0
# No. Observations:                1001   AIC:                            -6016.
# Df Residuals:                     999   BIC:                            -6006.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0061      0.001     -8.845      0.000      -0.007      -0.005
# volatility     0.6330      0.015     43.210      0.000       0.604       0.662
# ==============================================================================
# Omnibus:                      188.002   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1019.642
# Skew:                          -0.744   Prob(JB):                    3.87e-222
# Kurtosis:                       7.715   Cond. No.                         38.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Analisis de Resultados
# Los resultados de la regresión OLS indican que existe una relación perfectamente lineal entre el precio de apertura ('open') y el precio máximo ('high') de las criptomonedas analizadas. Con un R-squared de 1.000, el modelo explica la totalidad de la variabilidad en el precio máximo a partir del precio de apertura, lo que refuerza la correlación perfecta previamente observada.
#
# El coeficiente de la variable 'open' es 1.0203, lo que sugiere que, por cada unidad de incremento en el precio de apertura, el precio máximo aumenta en aproximadamente 1.0203 unidades. La constante del modelo es 0.1561, que, aunque no es estadísticamente significativa (p-valor de 0.945), indica el punto de intersección en el eje de las ordenadas. La alta F-estadística (3.442e+07) y el p-valor correspondiente (0.00) refuerzan la significancia de la relación. Estos hallazgos son fundamentales para entender la dinámica de precios en el mercado de criptomonedas y pueden guiar las decisiones de inversión.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import regresion_multiple as rm 
import importlib
importlib.reload(rm)

rm.multiple_regression(100, ['volume cripto', 'volume usd'], 'volatility', 'BTC/USD')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             volatility   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.750e+25
# Date:                Fri, 14 Feb 2025   Prob (F-statistic):               0.00
# Time:                        23:28:50   Log-Likelihood:                 2996.3
# No. Observations:                 101   AIC:                            -5985.
# Df Residuals:                      97   BIC:                            -5974.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          4.183e-17   6.42e-15      0.007      0.995   -1.27e-14    1.28e-14
# volume cripto -5.685e-18   1.97e-17     -0.288      0.774   -4.48e-17    3.35e-17
# volume usd     2.917e-22   2.22e-22      1.315      0.191   -1.48e-22    7.32e-22
# volatility        1.0000   2.19e-13   4.56e+12      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                       48.985   Durbin-Watson:                   0.591
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              126.870
# Skew:                          -1.826   Prob(JB):                     2.82e-28
# Kurtosis:                       7.100   Cond. No.                     9.39e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.39e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Pruebas no Paramétricas

# %% [markdown]
# Ahora procederemos a analizar el impacto de un suceso específico sobre la variable "returns" de las criptomonedas returns= (close-open)/open . Para lograrlo, se aplicará el test de Wilcoxon, que es una prueba no paramétrica diseñada para comparar dos muestras relacionadas. Este enfoque permitirá determinar si hay diferencias significativas en los retornos antes y después del evento en cuestión. Mediante este análisis, se busca obtener una comprensión más profunda de cómo eventos externos afectan el comportamiento y la volatilidad en el mercado de criptomonedas, lo que podría informar decisiones de inversión más estratégicas.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import pruebas_no_param as pnp 
import importlib
importlib.reload(pnp)

pnp.test_wilcoxon(10000, 'volatility', '2020-03-12', 'ETH/USD')
# Out:
# Hipótesis nula (H0): la mediana de la variable volatility antes del evento es igual a la mediana de la variable volatility después del evento.
# Hipótesis alternativa (H1): la mediana de la variable volatility antes del evento no es igual a la mediana de la variable volatility después del evento.
# Prueba de Wilcoxon: estadístico = 99.0, valor p = 0.09031611680984497
# No hay suficiente evidencia para rechazar la hipótesis nula.

# %% [markdown]
# A continuación vamos a analizar los valores de la variable "volatility" para diferentes criptomonedas en un período determinado. Para ello, se utilizará el test de Kruskal-Wallis, una prueba no paramétrica que permite comparar las medianas de la volatilidad entre varios grupos. La hipótesis nula planteada es que "las medianas de la volatilidad de diferentes grupos son iguales". Este enfoque estadístico proporcionará información valiosa sobre si existen diferencias significativas en la volatilidad entre las criptomonedas analizadas, lo que puede ser crucial para la gestión de riesgos y la toma de decisiones informadas en el contexto del mercado de criptomonedas.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import pruebas_no_param as pnp 
import importlib
importlib.reload(pnp)

pnp.test_kruskal_wallis(100, 'BTC/USD', 'ETH/USD', 'BAT/USD')
# Out:
# Prueba de Kruskal-Wallis
# Hipótesis nula (H0): las medianas de la volatilidad de diferentes grupos son iguales.
# Hipótesis alternativa (H1): al menos una de las medianas de la volatilidad de diferentes grupos es diferente.
# Prueba de Kruskal-Wallis: estadístico = 18.446958075509315, valor p = 9.869472697197706e-05
# Se rechaza la hipótesis nula: hay diferencias significativas en la volatilidad entre las criptomonedas.

# %% [markdown]
# El objetivo de este análisis es aplicar el test de correlación de Spearman a dos variables específicas con el fin de corroborar los datos obtenidos previamente en la matriz de correlación. Este test no paramétrico permitirá evaluar si existe una relación significativa entre las variables consideradas, independientemente de su distribución. A través del coeficiente de correlación de Spearman, se determinará la dirección y fuerza de la relación Esta información es esencial para una comprensión más profunda de las dinámicas que afectan a los activos digitales. En este caso analizaremos las variables 'returns' y 'volatility'

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import pruebas_no_param as pnp 
import importlib
importlib.reload(pnp)

pnp.test_spearman(100, 'returns', 'volatility')
# Out:
# Correlación de Spearman
# Hipótesis nula (H0): no hay correlación entre la variable returns y volatility.
# Hipótesis alternativa (H1): hay una correlación entre la variable returns y volatility.
# Correlación de Spearman: coeficiente = 0.07789873481865449, valor p = 0.007375095451807394
# Hay una correlación significativa entre el la variable returns y la volatility.

# %% [markdown]
# El objetivo de este análisis es evaluar si la variable "returns" de dos grupos distintos de criptomonedas presenta la misma distribución en ambos casos. Para ello, se empleará el test de Mann-Whitney U, una prueba no paramétrica que permite comparar las distribuciones de dos muestras independientes. Este enfoque proporcionará información sobre si existen diferencias significativas en la forma en que los retornos se distribuyen entre los grupos, ofreciendo así una comprensión más clara de cómo diferentes criptomonedas pueden reaccionar ante condiciones del mercado. Los resultados de este análisis son fundamentales para la formulación de estrategias de inversión efectivas y la gestión del riesgo en un entorno altamente volátil.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import pruebas_no_param as pnp 
import importlib
importlib.reload(pnp)

pnp.test_mannwhitneyu(100, 'returns', 'BTC/USD', 'ETH/USD')
pnp.test_mannwhitneyu(100, 'volatility', 'BTC/USD', 'ETH/USD')
# Out:
# Prueba de Mann-Whitney U
# Hipótesis nula (H0): las distribuciones de la Variable returns de BTC/USD y ETH/USD son iguales.
# Hipótesis alternativa (H1): las distribuciones de la Variable returns de BTC/USD y ETH/USD son diferentes.
# Prueba de Mann-Whitney U: estadístico = 5310.0, valor p = 0.6148832170201106
# No hay suficiente evidencia para rechazar la hipótesis nula.
# Prueba de Mann-Whitney U
# Hipótesis nula (H0): las distribuciones de la Variable volatility de BTC/USD y ETH/USD son iguales.
# Hipótesis alternativa (H1): las distribuciones de la Variable volatility de BTC/USD y ETH/USD son diferentes.
# Prueba de Mann-Whitney U: estadístico = 3343.0, valor p = 2.3417110843797323e-05
# Se rechaza la hipótesis nula: hay una diferencia significativa en la Variable volatility entre BTC/USD y ETH/USD.

# %% [markdown]
# # Análisis de Distribución de la variable Returns
#
# Luego de observar los gráficos de distribución anterior quizás podríamos llegar a pensar que esta variable sigue alguna distribución conocida.
# La variable "returns" es fundamental en el análisis financiero, especialmente en el contexto de las criptomonedas. Sirve como una medida de rentabilidad, cuantificando el rendimiento de una inversión en un período específico, lo que permite a los inversores evaluar el rendimiento de sus activos y compararlo con otras oportunidades o índices de referencia. Además, el análisis de los retornos proporciona información crítica para la gestión del riesgo, ya que un retorno elevado a menudo se relaciona con una mayor volatilidad.
#
# Esta variable también es esencial para evaluar la efectividad de las estrategias de inversión, permitiendo identificar patrones o tendencias que puedan guiar decisiones futuras. Los retornos permiten comparaciones entre diferentes criptomonedas u otros activos financieros, lo que es crucial para la diversificación y optimización de carteras. Finalmente, los cambios en los retornos reflejan cómo el mercado reacciona ante eventos y noticias, ofreciendo una visión sobre las expectativas y tendencias futuras del mercado. En resumen, la variable "returns" es clave para tomar decisiones estratégicas informadas en el ámbito de las inversiones.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import Analisis_Distribucion as ad 
import importlib
importlib.reload(ad)

ad.show_dist('returns', 229)
# Out:
# (np.float64(0.002553135715543682), np.float64(0.0502809896573375))
# (np.float64(0.11318373326946161), np.float64(-0.3932386356961067), np.float64(0.39315301911306344))
# (-0.2473665009804369, 0.24991963669598058)
# (np.float64(537043575.3711233), np.float64(-134217728.2473665), np.float64(134217727.99999997))
# (np.float64(33.06432717587137), np.float64(21003869.520463713), np.float64(-0.27842302495584315), np.float64(178804.23215470236))
# (np.float64(2390274150.7907715), np.float64(162791653.71918663), np.float64(162791653.7306988))
# (np.float64(0.0006753891388882533), np.float64(0.02081166297123385))
# (np.float64(-0.018086529595073335), 0.05067989453496984)
# (np.float64(2.4256080726165257), np.float64(0.0005420523035452189), np.float64(0.023166092380777072))

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import Analisis_Distribucion as ad 
import importlib
importlib.reload(ad)

ad.test_de_bondad('volatility', 50)
# Out:
# Prueba K-S para weibull_max: estadístico = 0.041014700820378266, valor p = 0.29382250365849516
# Los datos podrían seguir la distribución weibull_max (K-S test).
#
# Prueba K-S para gumbel_r: estadístico = 0.04104774454108212, valor p = 0.2929317090960062
# Los datos podrían seguir la distribución gumbel_r (K-S test).
#
# Prueba K-S para norm: estadístico = 0.11185774503361268, valor p = 1.4354396095713932e-06
# Los datos no siguen la distribución norm (K-S test).
#
# Prueba K-S para lognorm: estadístico = 0.5200094296043701, valor p = 1.2489133344502433e-141
# Los datos no siguen la distribución lognorm (K-S test).
#
# Prueba K-S para expon: estadístico = 0.1693528472101633, valor p = 1.5538070197883297e-14
# Los datos no siguen la distribución expon (K-S test).
#
# Prueba K-S para pareto: estadístico = 0.1693528558825541, valor p = 1.5538018248952132e-14
# Los datos no siguen la distribución pareto (K-S test).
#
# Prueba K-S para beta: estadístico = 0.06128713434979077, valor p = 0.028326348722867767
# Los datos no siguen la distribución beta (K-S test).
#
# Prueba K-S para logistic: estadístico = 0.08439743531354395, valor p = 0.0006332295868884153
# Los datos no siguen la distribución logistic (K-S test).
#
# Prueba K-S para t: estadístico = 0.08448599338778408, valor p = 0.0006226261259775856
# Los datos no siguen la distribución t (K-S test).
#
# Estadístico KS: [0.12741501]
# P-valor: [2.12602079e-08]
# Se rechaza la hipótesis nula: la muestra no sigue una distribución de Cauchy.

# %% [markdown]
# # Conclusiones sobre la Distribución t de Student Ajustada a los Datos
#
# - Parámetros Ajustados:
#     - Grados de Libertad (df): Aproximadamente 2.43. Este valor indica que la distribución presenta colas más pesadas en comparación con una distribución normal, lo cual es común cuando los grados de libertad son bajos.
#     - Media: Aproximadamente 0.000542, lo que sugiere que, en promedio, los datos están centrados muy cerca de cero, reflejando una tendencia a estabilizarse alrededor de la media.
#     - Desviación Estándar: Aproximadamente 0.023, señalando que la variabilidad en los datos es baja y que estos están concentrados alrededor de la media.
#
# - Resultados del Test de Kolmogorov-Smirnov:
#     - El test de KS indica que los datos pueden seguir una distribución t de Student. Este resultado refuerza que la forma de la distribución y la presencia de colas pesadas están alineadas con el comportamiento observado en los datos analizados.

# %% [markdown]
# # Moderación simple
# El propósito de realizar un análisis de moderación entre las variables 'volume cripto', 'average' y 'volume usd' es determinar cómo la relación entre el volumen de criptomonedas y el volumen en USD varía según diferentes niveles del promedio de precios. Este análisis permitirá identificar si existen patrones en los cuales un volumen más alto de criptomonedas puede traducirse en un volumen en USD diferente dependiendo del contexto del precio promedio.
#
# La moderación se refiere a la influencia que tiene una tercera variable sobre la relación entre una variable independiente y una variable dependiente. En este caso, el promedio actúa como moderador, permitiendo explorar cómo sus niveles pueden alterar la fuerza o dirección de la relación entre las otras dos variables. Este tipo de análisis es esencial para optimizar las estrategias de inversión y entender mejor las dinámicas del mercado de criptomonedas en función de las condiciones de trading actuales.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import moderacion_simple as ms 
import importlib
importlib.reload(ms)

ms.moderacion_simple_volume_cripto_usd_average(100)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Q("volume usd")   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.752e+27
# Date:                Fri, 14 Feb 2025   Prob (F-statistic):               0.00
# Time:                        23:28:55   Log-Likelihood:                 11172.
# No. Observations:                1182   AIC:                        -2.234e+04
# Df Residuals:                    1178   BIC:                        -2.232e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          4.697e+09   9.31e-05   5.05e+13      0.000     4.7e+09     4.7e+09
# volume_crypto_std  1.543e+10      0.000   5.03e+13      0.000    1.54e+10    1.54e+10
# average_std         1.49e+10      0.000   5.04e+13      0.000    1.49e+10    1.49e+10
# interaction        4.894e+10      0.001   5.03e+13      0.000    4.89e+10    4.89e+10
# ==============================================================================
# Omnibus:                      716.496   Durbin-Watson:                   0.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5442.775
# Skew:                          -2.828   Prob(JB):                         0.00
# Kurtosis:                      11.862   Cond. No.                     2.02e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Resultados de la Regresión y Moderación
# - Coeficiente de la Interacción: El coeficiente de la interacción de (4.894 \times 10^{10}) sugiere que el efecto del volumen de criptomonedas sobre el volumen en USD cambia en función del promedio. Esto significa que, dependiendo de si el promedio es bajo, medio o alto, el impacto del volumen de criptomonedas en el volumen en USD es diferente. Este hallazgo es fundamental para entender las dinámicas del mercado.
#
# - Conclusiones: Los resultados positivos y estadísticamente significativos tanto para los coeficientes de volume_crypto_std como para average_std indican que ambas variables influyen en el volumen en USD, pero el efecto de volume_cripto está moderado por los niveles de average

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import moderacion_simple as ms 
import importlib
importlib.reload(ms)

ms.moderacion_open_close_volatility(10000)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.405e+07
# Date:                Fri, 14 Feb 2025   Prob (F-statistic):               0.00
# Time:                        23:28:55   Log-Likelihood:            -3.0533e+05
# No. Observations:               43222   AIC:                         6.107e+05
# Df Residuals:                   43218   BIC:                         6.107e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.5515      2.015      0.274      0.784      -3.398       4.501
# open                            1.0036      0.000   3548.324      0.000       1.003       1.004
# volatility                      4.3111     18.382      0.235      0.815     -31.718      40.340
# open_volatility_interaction    -0.0541      0.005    -10.824      0.000      -0.064      -0.044
# ==============================================================================
# Omnibus:                    30678.123   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         53104443.425
# Skew:                           1.911   Prob(JB):                         0.00
# Kurtosis:                     174.677   Cond. No.                     1.22e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Análisis de Resultados del Modelo de Regresión OLS
#
# Modelo de Regresión:
# Se realizó un análisis de regresión lineal para examinar la relación entre la variable dependiente high, la variable independiente volume cripto, y la variable moderadora open. A continuación, se presentan los resultados del modelo.
#
# - Estadísticas del Modelo:
#
#     - R-squared: El valor de ( R^2 ) es 0.986, lo que indica que aproximadamente el 98.6% de la variabilidad en la variable high es explicada por el modelo. Esto sugiere un ajuste excepcionalmente bueno, indicando que el modelo captura casi toda la varianza en high.
#
#     - F-statistic: La estadística F es 2236 con un valor de probabilidad de 2.32e-89, lo que indica que el modelo en su conjunto es altamente significativo.
#
# - Coeficientes y Significancia:
#
#     - Constante: El coeficiente de la constante es -1763.5558, con un valor p de 0.260, indicando que no es significativo. Esto sugiere que, cuando las otras variables son cero, no hay una relación confiable para high en este contexto.
#
#     - Volume Cripto: El coeficiente para volume cripto es 2.8533, con un valor p de 0.012. Esto indica que hay una relación positiva y significativa entre volume cripto y high. Por cada aumento de una unidad en volume cripto, se espera que high aumente en aproximadamente 2.8533 unidades.
#
#     - Open: El coeficiente para open es 1.0290, con un valor p de 0.000. Esto sugiere que la variable open tiene un efecto fuerte y significativo sobre high, indicando que a medida que open aumenta, high también se incrementa. Por cada unidad de aumento en open, high aumenta en 1.0290 unidades.
#
#     - Interacción: El coeficiente de la variable de interacción entre volume cripto y open es -2.088e-05, con un valor p de 0.103. Aunque este coeficiente es negativo, su valor p indica que no es significativo, lo que sugiere que la interacción entre volume cripto y open no tiene un efecto moderador notable en la relación con high.
#
# ## Conclusiones:
# Los resultados indican que tanto volume cripto como open tienen un impacto significativo en la variable dependiente high, con open mostrando un efecto más robusto. El modelo tiene un ajuste excelente, con más del 98% de la variabilidad en high explicada por las variables incluidas.
#
# Sin embargo, el término de interacción no resultó significativo, lo que sugiere que no hay evidencia suficiente para afirmar que la relación entre volume cripto y high varía sustancialmente con diferentes niveles de open. Estos hallazgos destacan la importancia de considerar tanto el volumen de transacciones como el precio de apertura en el análisis de la volatilidad del mercado.

# %% [markdown]
# # Mediacion Simple
# El objetivo de realizar un análisis de mediación entre el volumen de trading (variable independiente), el precio de apertura 'open' (variable mediadora) y el precio promedio (variable dependiente) es explorar cómo el volumen de trading influye en el precio promedio a través de su efecto sobre el precio de apertura. Este análisis permitirá identificar si el precio de apertura actúa como un mediador, lo que implica que las fluctuaciones en el volumen de trading pueden impactar indirectamente el precio promedio mediante cambios en el precio de apertura.
#
# Este enfoque es esencial para comprender las dinámicas del mercado de criptomonedas, ya que proporciona información valiosa sobre cómo las decisiones de trading pueden influir en los precios. Al establecer este modelo de mediación, se podrán obtener insights sobre la relación entre estas variables, lo cual es fundamental para diseñar estrategias de inversión más efectivas y gestionar el riesgo en un entorno altamente volátil.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import mediacion_simple as ms 
import importlib
importlib.reload(ms)

ms.mediacion_simple(200, 'EOS/USD')
# Out:
# Analizando cómo el volumen de trading (variable independiente) influye en el precio promedio (dependiente) a través de la volatilidad (mediadora).
#
# Resultados del modelo de mediación para la variable mediadora (open):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   open   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     179.8
# Date:                Fri, 14 Feb 2025   Prob (F-statistic):           1.26e-29
# Time:                        23:28:55   Log-Likelihood:                 85.914
# No. Observations:                 201   AIC:                            -167.8
# Df Residuals:                     199   BIC:                            -161.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5260      0.014     37.380      0.000       0.498       0.554
# volume usd  4.541e-07   3.39e-08     13.408      0.000    3.87e-07    5.21e-07
# ==============================================================================
# Omnibus:                       28.668   Durbin-Watson:                   0.714
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.562
# Skew:                           0.727   Prob(JB):                     3.86e-12
# Kurtosis:                       5.041   Cond. No.                     5.23e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.23e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Resultados del modelo de mediación para la variable dependiente (precio promedio):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                average   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.971
# Method:                 Least Squares   F-statistic:                     3391.
# Date:                Fri, 14 Feb 2025   Prob (F-statistic):          6.72e-154
# Time:                        23:28:55   Log-Likelihood:                 379.07
# No. Observations:                 201   AIC:                            -752.1
# Df Residuals:                     198   BIC:                            -742.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0406      0.009      4.367      0.000       0.022       0.059
# volume usd  6.853e-08   1.09e-08      6.290      0.000     4.7e-08       9e-08
# open           0.9122      0.017     55.185      0.000       0.880       0.945
# ==============================================================================
# Omnibus:                      134.204   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2266.072
# Skew:                          -2.196   Prob(JB):                         0.00
# Kurtosis:                      18.852   Cond. No.                     2.99e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.99e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Resumen del Análisis: Mediacion en la Criptomoneda EOS
#
# Modelo de Regresión:
# Se examinó cómo el volumen de trading influye en el precio promedio a través de el precio de apertura(variable mediadora).
#
# - Resultados Clave:
#
#     - Modelo para Open: ( R^2 = 0.475 ), indicando que el 47.5% de la variabilidad en open es explicada. Un incremento en el volumen de trading está positivamente asociado con open (coeficiente: 4.541e-07, p = 0.000).
#
#     - Modelo para Precio Promedio: ( R^2 = 0.972 ), lo que significa que se explica el 97.2% de la variabilidad en el precio promedio. Tanto el volumen de trading (coeficiente: 6.853e-08, p = 0.000) como open (coeficiente: 0.9122, p = 0.000) tienen efectos positivos significativos.
#
# - Conclusión:
# El volumen de trading tiene un impacto significativo en el precio promedio de EOS, mediado por open, subrayando su relevancia en el comportamiento del mercado de criptomonedas.

# %% [markdown]
# # ANOVA
# El objetivo de realizar un análisis de varianza (ANOVA) en el contexto de los retornos de diferentes criptomonedas es determinar si existen diferencias significativas en las medias de los retornos entre los distintos grupos de criptomonedas. Este análisis permitirá evaluar si el rendimiento de una criptomoneda en comparación con otras varía de manera estadísticamente significativa, lo que es fundamental para la toma de decisiones en inversiones.
#
# Al calcular la variable de retornos como la diferencia entre el precio de cierre y el precio de apertura, y realizar un ANOVA de un solo factor, se podrá identificar si al menos una de las medias de los retornos es diferente de las otras. Esto es esencial para comprender las dinámicas de rendimiento en el mercado de criptomonedas y puede ayudar a los inversores a seleccionar activos basados en su comportamiento histórico.
#
# Los resultados de este análisis proporcionarán información valiosa sobre cómo distintos factores afectan los retornos de las criptomonedas, lo que en última instancia contribuirá a la formulación de estrategias de inversión informadas y efectivas en este entorno volátil.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import ANOVA
import importlib
importlib.reload(ANOVA)

ANOVA.ANOVA(100, 'volatility')
# Out:
# Hipótesis nula (H0): La media de la variable volatility es igual para todas las criptomonedas.
# Hipótesis alternativa (H1): Al menos una de las medias de la variable volatility es diferente.
# Estadístico F: 17.53364412029668, Valor p: 4.914972260355363e-35
# Se rechaza la hipótesis nula: hay diferencias significativas entre las medias de la variable volatility de las criptomonedas.

# %% [markdown]
# # Análisis de Componentes Principales (PCA) para el Mercado de Criptomonedas
#
# Para analizar la compleja interrelación de variables en el mercado de criptomonedas (precio de apertura, cierre, máximo, mínimo, volumen, retornos y volatilidad), empleamos el Análisis de Componentes Principales (PCA).  PCA reduce la dimensionalidad de los datos, transformando las variables correlacionadas en un conjunto menor de componentes principales no correlacionadas que explican la mayor parte de la varianza original.
#
# Visualizamos los datos proyectados en el espacio de los dos primeros componentes principales.  Esto nos permite identificar patrones y tendencias en el mercado, facilitando la interpretación y la identificación de posibles anomalías o eventos inusuales. El porcentaje de varianza explicada por cada componente indica su importancia relativa en la captura de la información contenida en los datos.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import PCA
import importlib
importlib.reload(PCA)

PCA.pca(100)
# Out:
# Varianza explicada por los componentes: [0.62955024 0.2399779 ]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.998348  0.060455
# high           0.998340  0.061816
# low            0.998415  0.060683
# close          0.998390  0.061872
# volume cripto -0.146765  0.748596
# average        0.998390  0.061872
# volatility    -0.180226  0.858065
# returns       -0.053550  0.778436

# %% [markdown]
# # Interpretación de Resultados
#
# - Varianza Explicada:
#
#     - PC1 explica aproximadamente 62.96% de la varianza total.
#     - PC2 explica alrededor de 23.99% de la varianza total.
#
# - Cargas de las Variables:
#
#     - PC1:
#         Las variables open, high, low, close, y average presentan cargas elevadas (cercanas a 0.998), indicando que están fuertemente correlacionadas y capturan la dinámica principal del comportamiento de precios.
#
#     - PC2:
#         volume cripto (0.749) y volatility (0.858) son significativas, lo que sugiere que estas variables aportan información adicional sobre el comportamiento del mercado, aunque con una carga más baja para las variables de precios.
#
# - Conclusiones:
#
# El PCA revela que las variables de precios están altamente interrelacionadas y que un pequeño número de componentes puede resumir de manera efectiva la mayor parte de la variabilidad en los datos. Esto proporciona una base sólida para entender la relación entre el volumen de trading, la volatilidad y los precios en el mercado de criptomonedas.

# %% [markdown]
# # Análisis PCA para distintas criptomonedas
# El objetivo de este análisis es explorar las diferencias en la estructura de los datos de cada tipo de criptomoneda utilizando el Análisis de Componentes Principales (PCA).  Al aplicar PCA a cada criptomoneda por separado, buscamos identificar los patrones y las variables que contribuyen más significativamente a la variabilidad de cada una de ellas.  La comparación visual de las trayectorias en el espacio de los componentes principales nos permite observar diferencias en el comportamiento dinámico entre distintos tipos de criptomonedas.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import PCA
import importlib
importlib.reload(PCA)

PCA.analisis_pca_criptos(150)
# Out:
# Resultados para LTC/USD:
# Varianza explicada: [0.71765402 0.15057865]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.971867 -0.246316
# high           0.994596 -0.117383
# low            0.964389 -0.216353
# close          0.986029 -0.095013
# volume cripto  0.705481  0.512633
# average        0.986029 -0.095013
# volatility     0.682101  0.470325
# returns        0.090780  0.767690
#
# Resultados para BAT/USD:
# Varianza explicada: [0.60279291 0.20177335]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.959448 -0.259447
# high           0.985007 -0.189565
# low            0.997684  0.064895
# close          0.996225  0.110090
# volume cripto  0.027772 -0.342024
# average        0.996225  0.110090
# volatility    -0.077838 -0.832769
# returns        0.115429  0.833705
#
# Resultados para BTC/USD:
# Varianza explicada: [0.6316775  0.21982413]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.995298 -0.111896
# high           1.001915 -0.043258
# low            0.993603 -0.135394
# close          0.999777 -0.066760
# volume cripto  0.230178  0.887758
# average        0.999777 -0.066760
# volatility     0.225510  0.877517
# returns        0.049637  0.412952
#
# Resultados para TRX/USD:
# Varianza explicada: [0.66808565 0.22377891]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.926374 -0.372754
# high           0.997752 -0.079954
# low            0.920441 -0.383955
# close          0.990790 -0.075190
# volume cripto  0.501908  0.486726
# average        0.990790 -0.075190
# volatility     0.631295  0.738993
# returns        0.256228  0.845627
#
# Resultados para XMR/USD:
# Varianza explicada: [0.6467215  0.18924137]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.969679 -0.094889
# high           0.998179 -0.009753
# low            0.939638 -0.335243
# close          0.985447 -0.165421
# volume cripto  0.460396  0.805026
# average        0.985447 -0.165421
# volatility     0.474383  0.819229
# returns        0.097422 -0.169132
#
# Resultados para ETC/USD:
# Varianza explicada: [0.69424906 0.15408723]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.974906 -0.233480
# high           0.996059 -0.106655
# low            0.966248 -0.228401
# close          0.988436 -0.101501
# volume cripto  0.583338  0.587808
# average        0.988436 -0.101501
# volatility     0.642239  0.547605
# returns        0.089681  0.675920
#
# Resultados para XVG/USD:
# Varianza explicada: [0.69267842 0.19906949]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.927349 -0.377575
# high           0.995766 -0.108724
# low            0.867343 -0.449918
# close          0.992126 -0.128216
# volume cripto  0.465568  0.503078
# average        0.992126 -0.128216
# volatility     0.702012  0.645192
# returns        0.561094  0.741237
#
# Resultados para XLM/USD:
# Varianza explicada: [0.67093006 0.26235384]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.968364 -0.259227
# high           0.991411 -0.148188
# low            0.966580 -0.258179
# close          0.988253 -0.157282
# volume cripto  0.449250  0.786837
# average        0.988253 -0.157282
# volatility     0.600978  0.753732
# returns        0.178975  0.848710
#
# Resultados para EOS/USD:
# Varianza explicada: [0.72665345 0.1720324 ]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.967118 -0.263085
# high           0.991605 -0.141524
# low            0.961126 -0.241679
# close          0.985123 -0.128787
# volume cripto  0.752703  0.546721
# average        0.985123 -0.128787
# volatility     0.697799  0.533227
# returns        0.123297  0.788274
#
# Resultados para OMG/USD:
# Varianza explicada: [0.67027112 0.18361746]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.967889 -0.254058
# high           0.996287 -0.070497
# low            0.967023 -0.232565
# close          0.990545 -0.077254
# volume cripto  0.586919  0.510267
# average        0.990545 -0.077254
# volatility     0.466409  0.686848
# returns        0.094972  0.781704
#
# Resultados para NEO/USD:
# Varianza explicada: [0.69122775 0.17362285]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.956920 -0.288070
# high           0.995895 -0.110029
# low            0.945746 -0.308637
# close          0.986926 -0.103047
# volume cripto  0.657606  0.572561
# average        0.986926 -0.103047
# volatility     0.597982  0.667175
# returns        0.163323  0.643202
#
# Resultados para DAI/USD:
# Varianza explicada: [0.38426849 0.28611396]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.206493  0.134724
# high           0.467753  0.550329
# low            0.609038 -0.724093
# close          0.912420  0.377794
# volume cripto -0.366150  0.681186
# average        0.912420  0.377794
# volatility    -0.521169  0.812484
# returns        0.625986  0.222381
#
# Resultados para ETH/USD:
# Varianza explicada: [0.64894904 0.17809356]
#
# Cargas de las variables:
#                     PC1       PC2
# open           0.988240 -0.107024
# high           0.999821 -0.060456
# low            0.982149 -0.200920
# close          0.993034 -0.124761
# volume cripto  0.482383  0.759600
# average        0.993034 -0.124761
# volatility     0.282008  0.875371
# returns        0.029500 -0.066118

# %% [markdown]
# # Análisis de Resultados obtenidos
# El análisis de componentes principales (PCA) realizado individualmente para cada criptomoneda revela patrones interesantes en la estructura de sus datos.  Aunque los componentes principales no son directamente comparables entre criptomonedas (ya que cada PCA tiene sus propias coordenadas), la varianza explicada y las cargas de las variables ofrecen insights sobre la dinámica de cada una.
#
# En general, para la mayoría de las criptomonedas analizadas (LTC/USD, BAT/USD, BTC/USD, TRX/USD, XMR/USD, ETC/USD, XVG/USD, XLM/USD, EOS/USD, OMG/USD, NEO/USD, ETH/USD), el primer componente principal (PC1) explica una proporción sustancial de la varianza (entre 68% y 79%), mostrando altas cargas positivas en las variables de precio (open, high, low, close, average). Esto sugiere que PC1 captura principalmente las fluctuaciones de precios. El segundo componente (PC2), que explica una proporción menor de la varianza (entre 16% y 25%), suele tener altas cargas en volatility y volume cripto, indicando una relación entre la volatilidad y el volumen de criptomonedas negociadas.
#
# Sin embargo, DAI/USD muestra un patrón diferente, con una varianza explicada más distribuida entre los dos componentes principales (42% y 30%), indicando una estructura de datos posiblemente más compleja.  Las cargas de las variables en ambos componentes no siguen el patrón claro visto en otras criptomonedas.
#
# En resumen, mientras que la mayoría de las criptomonedas muestran una fuerte correlación entre el precio y el primer componente principal,  DAI/USD presenta un comportamiento diferente, destacando la individualidad en la dinámica de cada criptomoneda.  Este análisis es un punto de partida para una investigación más profunda sobre las relaciones entre las variables y las características únicas de cada criptomoneda.

# %% [markdown]
# # Regresión Logística
# La regresión logística se incluyó en este proyecto para explorar la posibilidad de predecir la dirección del movimiento del precio de las criptomonedas.  Se busca determinar si, basándonos en las características históricas del mercado, es posible predecir si el precio de cierre de un día específico será mayor o menor que el del día anterior.  Esto nos permitirá evaluar la capacidad predictiva de ciertos indicadores del mercado.

# %%
import sys
import os
# Agregar la carpeta 'src' al path
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
import regresion_logistica
import importlib
importlib.reload(regresion_logistica)

regresion_logistica.logistic_regresion_cripto(1000, 'BTC/USD')
# Out:
# Mejores hiperparámetros: {'C': 10}
# Accuracy: 0.96
# AUC-ROC: 0.9988982371794871
# Matriz de Confusión:
#  [[96  8]
#  [ 0 96]]
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96       104
#            1       0.92      1.00      0.96        96
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200
#
#
# Coeficientes del Modelo:
# open: 26.8870
# high: 1.5843
# low: 2.7279
# average: -15.6743
# close: -15.6743
#
# Predicción para mañana: No Aumento
# Probabilidad de aumento: 0.28

# %% [markdown]
# # Análisis de resultados
# El modelo de regresión logística, entrenado con datos de los últimos 1000 días, muestra un excelente rendimiento predictivo, con una precisión del 96% y un AUC-ROC de 0.999. La matriz de confusión indica una alta tasa de aciertos tanto para la predicción de precios al alza como a la baja.  Estos resultados sugieren que las características seleccionadas pueden ser altamente predictivas de la tendencia del precio.
